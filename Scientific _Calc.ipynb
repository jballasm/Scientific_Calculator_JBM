# %%
import math
class scientific_calculator():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
    def addition(num1,num2):
        print('Addition: ', num1+num2)
    def substraction(num1,num2):
        print('Substraction: ', num1-num2)
    def multiplication(num1,num2):
        print('Multiplication: ', num1*num2)
    def division(num1,num2):
        print('Division: ', num1/num2)
    def sqrt(num1):
        print('Square root: ',math.sqrt(num1))
    def exponent(num1,num2):
        print('Exponent: ',math.pow(num1,num2))
    def logarithm(num1,num2):
        print('Logarithm x: ', math.log(num1,num2))
    def tangent(num1):
        print('Tangent: ', math.tan(num1))
    def sine(num1):
        print('Sine: ',math.sin(num1))
    def cosine(num1):
        print('Cosine: ',math.cos(num1))
    def pi():
        print('Pi: ',math.pi)
    def inverse_hyperbolic_cosine(num1):
        print('Inverse hyperbolic cosine: ',math.acosh(num1))
    def e():
        print('e constant: ',math.e)
    def inverse_hyperbolic_sine(num1):
        print('Inverse hyperbolic sine: ',math.asinh(num1))
    def arc_tangent(num1):
        print('Arc tangent: ',math.atan(num1))
    def tau():
        print('tau constant: ',math.tau)
    def hyperbolic_cosine(num1):
        print('Hyperbolic cosine: ',math.cosh(num1))
    def hyperbolic_sine(num1):
        print('Hyperbolic sine: ',math.sinh(num1))
    def hyperbolic_tangent(num1):
        print('Hyperbolic tangent: ',math.tanh(num1))
    def hypotenuse(num1,num2):
        print('Hypotenuse: ',math.hypot(num1,num2))
    
        
        
        
while True:
    print('Select a number: ')
    print('1: Addition')
    print('2: Substraction')
    print('3: Multiplication')
    print('4: Division')
    print('5: Square root(sqrt)')
    print('6: Exponent(pow)')
    print('7: Logarithm(log)')
    print('8: Tangent(tan)')
    print('9: Sine(sin)')
    print('10: Cosine(cos)')
    print('11: Pi(pi)')
    print('12: Inverse hyperbolic cosine(acosh)')
    print('13: e constant(e)')
    print('14: Inverse hyperbolic sine(asinh)')
    print('15: Arc tangent(atan)')
    print('16: tau constant(tau)')
    print('17: Hyperbolic cosine(cosh)')
    print('18: Hyperbolic sine(sinh)')
    print('19: Hyperbolic tangent(tanh)')
    print('20: Hypotenuse(hypot)')
    print('21: Exit')
    choice=int(input('Enter your choice (1-21): '))
    
    if choice==1:
        num1=int(input('Enter the first number here: '))
        num2=int(input('Enter the second number here: '))
        scientific_calculator.addition(num1,num2)
    elif choice==2:
        num1=int(input('Enter the first number here: '))
        num2=int(input('Enter the second number here: '))
        scientific_calculator.substraction(num1,num2)
    elif choice==3:
        num1=int(input('Enter the first number here: '))
        num2=int(input('Enter the second number here: '))
        scientific_calculator.multiplication(num1,num2)
    elif choice==4:
        num1=int(input('Enter numerator here: '))
        num2=int(input('Enter denominator here: '))  
        if num2==0:
            print('Infinity')
        else:
            scientific_calculator.division(num1,num2)
    elif choice==5:
        num1=int(input('Enter your number here: '))
        scientific_calculator.sqrt(num1)
    elif choice==6:
        num1=int(input('Enter base number: '))
        num2=int(input('Enter power here: '))
        scientific_calculator.exponent(num1,num2)
    elif choice==7:
        num1=int(input('Enter argument here: '))
        num2=int(input('Enter base here: '))
        scientific_calculator.logarithm(num1,num2)
    elif choice==8:
        num1=int(input('Enter your number here: '))
        scientific_calculator.tangent(num1)
    elif choice==9:
        num1=int(input('Enter your number here: '))
        scientific_calculator.sine(num1)
    elif choice==10:
        num1=int(input('Enter your number here: '))
        scientific_calculator.cosine(num1)
    elif choice==11:
        scientific_calculator.pi()
    elif choice==12:
        num1=int(input('Enter your number here: '))
        scientific_calculator.inverse_hyperbolic_cosine(num1)
    elif choice==13:
        scientific_calculator.e()
    elif choice==14:
        num1=int(input('Enter your number here: '))
        scientific_calculator.inverse_hyperbolic_sine(num1)
    elif choice==15:
        num1=int(input('Enter your number here: '))
        scientific_calculator.arc_tangent(num1)
    elif choice==16:
        scientific_calculator.tau()
    elif choice==17:
        num1=int(input('Enter your number here: '))
        scientific_calculator.hyperbolic_cosine(num1)
    elif choice==18:
        num1=int(input('Enter your number here: '))
        scientific_calculator.hyperbolic_sine(num1)
    elif choice==19:
        num1=int(input('Enter your number here: '))
        scientific_calculator.hyperbolic_tangent(num1)
    elif choice==20:
        num1=int(input('Enter first side here: '))
        num=int(input('Enter second side here: '))
        scientific_calculator.hypotenuse(num1,num2)
    elif choice==21:
        break
    else:
        print('Wrong choice. Choose a number between 1 to 21')
# Out:
# Select a number:
# 1: Addition
# 2: Substraction
# 3: Multiplication
# 4: Division
# 5: Square root(sqrt)
# 6: Exponent(pow)
# 7: Logarithm(log)
# 8: Tangent(tan)
# 9: Sine(sin)
# 10: Cosine(cos)
# 11: Pi(pi)
# 12: Inverse hyperbolic cosine(acosh)
# 13: e constant(e)
# 14: Inverse hyperbolic sine(asinh)
# 15: Arc tangent(atan)
# 16: tau constant(tau)
# 17: Hyperbolic cosine(cosh)
# 18: Hyperbolic sine(sinh)
# 19: Hyperbolic tangent(tanh)
# 20: Hypotenuse(hypot)
# 21: Exit
# Enter your choice (1-21): 16
# tau constant:  6.283185307179586
# Select a number:
# 1: Addition
# 2: Substraction
# 3: Multiplication
# 4: Division
# 5: Square root(sqrt)
# 6: Exponent(pow)
# 7: Logarithm(log)
# 8: Tangent(tan)
# 9: Sine(sin)
# 10: Cosine(cos)
# 11: Pi(pi)
# 12: Inverse hyperbolic cosine(acosh)
# 13: e constant(e)
# 14: Inverse hyperbolic sine(asinh)
# 15: Arc tangent(atan)
# 16: tau constant(tau)
# 17: Hyperbolic cosine(cosh)
# 18: Hyperbolic sine(sinh)
# 19: Hyperbolic tangent(tanh)
# ...
